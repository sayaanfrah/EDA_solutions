# %% [markdown]
# # Problem Statement :

# %% [markdown]
# Build a regressor model which will predict the CMS(Concrete Compresive Strength).Compressive Strength is the load acting per unit area.It is the mamximum strength upto Which a material can be compressed it is oppostite to that of the Tenstile strength

# %% [markdown]
# # Loading the Data from the Local System

# %%
import pandas as pd
df=pd.read_excel("Concrete_Data.xls")
df
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %% [markdown]
# # Understanding the Dataset

# %% [markdown]
# There are 9 columns in the dataset mainly :
#
# 1. Cement (component 1)(kg in a m^3 mixture)
# 2. Blast Furnace Slag (component 2)(kg in a m^3 mixture)
# 3. Fly Ash (component 3)(kg in a m^3 mixture)
# 4.  Water  (component 4)(kg in a m^3 mixture)
# 5. Superplasticizer (component 5)(kg in a m^3 mixture)
# 6. Coarse Aggregate  (component 6)(kg in a m^3 mixture)
# 7. Fine Aggregate (component 7)(kg in a m^3 mixture)
# 8. Age (day)
# 9. Concrete compressive strength(MPa, megapascals)
#
#
# Cement (component 1)(kg in a m^3 mixture) : It shows the density of the cement Since the unit of the column is kg/m^3.The unit of density is also Kilogram per cubic meter.
#
# Blast Furnace Slag (component 2)(kg in a m^3 mixture): It shows the density of the slag formed in the blast furnace.This is basically the residue which is left  in the furnace after the heating .it remains in the fluid form .
#
# Fly Ash (component 3)(kg in a m^3 mixture):It shows the density of the Ash left after heating the furnace .
#
# Water  (component 4)(kg in a m^3 mixture):It shows the density of the water required during the burninin og the furnace.
#
# Superplasticizer (component 5)(kg in a m^3 mixture): It is also known as high range water reducers ,are additives used in making high strength conerete.The Column shows its density
#
# Coarse Aggregate  (component 6)(kg in a m^3 mixture):it is Construction aggregate, or simply aggregate, is a broad category of coarse- to medium-grained particulate material used in construction, including sand, gravel, crushed stone, slag, recycled concrete and geosynthetic aggregates. Aggregates are the most mined materials in the world. This column shows its density
#
# Fine Aggregate (component 7)(kg in a m^3 mixture):It shows the density of Fine Aggregate used in blast furnace
#
# Age (day):This column gives the idea of how old the suppliers are .
#
# Concrete compressive strength(MPa, megapascals): Concrete compressive strength is basically the load per unit area.It also gives the yielding strength and life of the concrete used in its building .

# %%
df.columns
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %% [markdown]
# # EDA

# %% [markdown]
# # Scatterplot:

# %%
import seaborn as sns
sns.scatterplot(x="Age (day)",y="Concrete compressive strength(MPa, megapascals) ",data=df)
# Out:
# <AxesSubplot:xlabel='Age (day)', ylabel='Concrete compressive strength(MPa, megapascals) '>

# %% [markdown]
# it shows that in the startring the strength is weak but it solidifies with time and again looses its strength

# %%
sns.scatterplot(x="Fine Aggregate (component 7)(kg in a m^3 mixture)",y="Concrete compressive strength(MPa, megapascals) ",data=df)
# Out:
# <AxesSubplot:xlabel='Fine Aggregate (component 7)(kg in a m^3 mixture)', ylabel='Concrete compressive strength(MPa, megapascals) '>

# %% [markdown]
# The Outcome shows with the density of 750 to 900 fine aggregate ,maximum compressive strength lies

# %%
sns.scatterplot(x="Coarse Aggregate  (component 6)(kg in a m^3 mixture)",y="Concrete compressive strength(MPa, megapascals) ",data=df)
# Out:
# <AxesSubplot:xlabel='Coarse Aggregate  (component 6)(kg in a m^3 mixture)', ylabel='Concrete compressive strength(MPa, megapascals) '>

# %% [markdown]
# the outcome shows with the density of 950 to 1100 coarse aggregate maximum compressive strength lies

# %%
sns.scatterplot(x="Superplasticizer (component 5)(kg in a m^3 mixture)",y="Concrete compressive strength(MPa, megapascals) ",data=df)
# Out:
# <AxesSubplot:xlabel='Superplasticizer (component 5)(kg in a m^3 mixture)', ylabel='Concrete compressive strength(MPa, megapascals) '>

# %% [markdown]
# The Outcome shows with the density as it increases the becomes less.

# %%
sns.scatterplot(x="Water  (component 4)(kg in a m^3 mixture)",y="Concrete compressive strength(MPa, megapascals) ",data=df)
# Out:
# <AxesSubplot:xlabel='Water  (component 4)(kg in a m^3 mixture)', ylabel='Concrete compressive strength(MPa, megapascals) '>

# %% [markdown]
# The Outcome shows witht the density of 160 to 210 of water,maximum compressive strength lies

# %%
sns.scatterplot(x="Fly Ash (component 3)(kg in a m^3 mixture)",y="Concrete compressive strength(MPa, megapascals) ",data=df)
# Out:
# <AxesSubplot:xlabel='Fly Ash (component 3)(kg in a m^3 mixture)', ylabel='Concrete compressive strength(MPa, megapascals) '>

# %% [markdown]
# The Outcome shows with the density of 100 to 175 of fly ash where maximum compressive strength lies

# %%
sns.scatterplot(x="Blast Furnace Slag (component 2)(kg in a m^3 mixture)",y="Concrete compressive strength(MPa, megapascals) ",data=df)
# Out:
# <AxesSubplot:xlabel='Blast Furnace Slag (component 2)(kg in a m^3 mixture)', ylabel='Concrete compressive strength(MPa, megapascals) '>

# %% [markdown]
# The Outcome shows with the density of 0 to 210 where maximum number of compressive strength is lies.

# %%
sns.scatterplot(x="Cement (component 1)(kg in a m^3 mixture)",y="Concrete compressive strength(MPa, megapascals) ",data=df)
# Out:
# <AxesSubplot:xlabel='Cement (component 1)(kg in a m^3 mixture)', ylabel='Concrete compressive strength(MPa, megapascals) '>

# %% [markdown]
# The  Outcome show with the density of 100 to 400 where maximum number of compressive strength lies

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                                                     Cement (component 1)(kg in a m^3 mixture)  \
# Cement (component 1)(kg in a m^3 mixture)                                            1.000000
# Blast Furnace Slag (component 2)(kg in a m^3 mi...                                  -0.275193
# Fly Ash (component 3)(kg in a m^3 mixture)                                          -0.397475
# Water  (component 4)(kg in a m^3 mixture)                                           -0.081544
# Superplasticizer (component 5)(kg in a m^3 mixt...                                   0.092771
# Coarse Aggregate  (component 6)(kg in a m^3 mix...                                  -0.109356
# Fine Aggregate (component 7)(kg in a m^3 mixture)                                   -0.222720
# Age (day)                                                                            0.081947
# Concrete compressive strength(MPa, megapascals)                                      0.497833
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="black",fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation

# %% [markdown]
# from the above result it is clear that , some columns making positive corelation and some columns make negative correlation
#
# Columns making Positive Correlation
#
# 1. Age (day)
# 2. Cement (component 1)(kg in a m^3 mixture)
# 3. Blast Furnace Slag (component 2)(kg in a m^3 mixture)
# 4. Superplasticizer (component 5)(kg in a m^3 mixture)
#
# Columns making Negative Correlaltion
#
# 1. Fly Ash (component 3)(kg in a m^3 mixture)
# 2. Water (component 4)(kg in a m^3 mixture)
# 3. Coarse Aggregate (component 6)(kg in a m^3 mixture)
# 4. Fine Aggregate (component 7)(kg in a m^3 mixture)
#
#
# The Positively co-related columns has a great impact on the traget column while the negative correlated has less or zero impact on the target column

# %% [markdown]
# # Describe Heatmap

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidths=0.6,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variable Summary")
plt.show()

# %% [markdown]
# # Description of DataSets

# %%
df.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  \
# count                                1030.000000
# mean                                  281.165631
# std                                   104.507142
# min                                   102.000000
# 25%                                   192.375000
# 50%                                   272.900000
# 75%                                   350.000000
# max                                   540.000000
#
#        Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# count                                        1030.000000
# mean                                           73.895485
# std                                            86.279104
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            22.000000
# 75%                                           142.950000
# ...

# %% [markdown]
# # HeatMap and Describe Finding...

# %% [markdown]
# from the above plotting we are determining ,mean,standard deviation minimum and maximum valueof each column .It helps us further in data cleaning
#
# Total Number of Rows in DataSet
# 1. 1030 rows
# 2. 9 columns
#
# Cement(component 1)(kg in a m^3 mixture )
# 1. mean=281.16
# 2. standard_deviation=104.50
# 3. min_value=102
# 4. max_value=540
#
#
#
#
# Blast Furnace Slag(component 2)(kg in a m^3 mixture )
# 1. mean=73.89
# 2. std=86.27
# 3. minimum_value=0
# 4. max_value=359.40
#
#
#
# Fly Ash(component 3)(kg in a m^3 mixture )
# 1. mean=54.18
# 2. std=63.99
# 3. min_value=0
# 4. max_value=200
#
#
#
# Water (Component 4)(kg in a m^3 mixture )
# 1. mean=181.56
# 2. std=21.35
# 3. min_value=121.75
# 4. max_value=247
#
#
#
#
# Superplasticizer (Component 5)(kg in a m^3 mixture )
# 1. mean=6.20
# 2. std=5.97
# 3. min_value=0
# 4. max_value=32
#
#
#
# Coarse Aggregate(Component 6)(kg in a m^3 mixture )
# 1. mean=972
# 2. std=77.75
# 3. min_value=801
# 4. max-value=1145
#
#
#
#
# Fine Aggregate(Component 7)(kg in a m^3 mixture )
# 1. mean=773.57
# 2. std=80
# 3. min_value=594
# 4. max_value=992
#
#
#
#
# Age (day)
# 1. mean=45.66
# 2. std=63.16
# 3. min_value=1
# 4. max_value=365
#
#
#
# Concrete compressive strength(MPa, megapascals)
# 1. mean=35.81
# 2. std=16.70
# 3. min_value=2.33
# 4. max_value=82.59

# %% [markdown]
# # Now we use Subplot and Distplots to check, data is Normalized or not

# %%
import warnings
warnings.filterwarnings("ignore")
import itertools
cols=["Cement (component 1)(kg in a m^3 mixture)","Blast Furnace Slag (component 2)(kg in a m^3 mixture)",
"Fly Ash (component 3)(kg in a m^3 mixture)","Water  (component 4)(kg in a m^3 mixture)",
"Superplasticizer (component 5)(kg in a m^3 mixture)","Coarse Aggregate  (component 6)(kg in a m^3 mixture)",
"Fine Aggregate (component 7)(kg in a m^3 mixture)","Age (day)"]

length=len(cols)
cs=["b","r","g","c","m","k","lime"]
fig=plt.figure(figsize=(13,25))


for i,j,k in itertools.zip_longest(cols,range(length),cs):
    plt.subplot(4,2,j+1)
    ax=sns.distplot(df[i],color=k,rug=True)
    ax.set_facecolor("w")
    plt.axvline(df[i].mean(),linestyle='dashed',label='mean',color='k')
    plt.legend(loc='best')
    plt.title(i,color="navy")
    plt.xlabel("")

# %% [markdown]
# # Observation

# %% [markdown]
# From the above observation it is clear that , the data are not normalized and we should proceed with the data cleaning method

# %%
df.hist(edgecolor='red',linewidth=1.5,figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'Cement (component 1)(kg in a m^3 mixture)'}>,
#         <AxesSubplot:title={'center':'Blast Furnace Slag (component 2)(kg in a m^3 mixture)'}>,
#         <AxesSubplot:title={'center':'Fly Ash (component 3)(kg in a m^3 mixture)'}>],
#        [<AxesSubplot:title={'center':'Water  (component 4)(kg in a m^3 mixture)'}>,
#         <AxesSubplot:title={'center':'Superplasticizer (component 5)(kg in a m^3 mixture)'}>,
#         <AxesSubplot:title={'center':'Coarse Aggregate  (component 6)(kg in a m^3 mixture)'}>],
#        [<AxesSubplot:title={'center':'Fine Aggregate (component 7)(kg in a m^3 mixture)'}>,
#         <AxesSubplot:title={'center':'Age (day)'}>,
#         <AxesSubplot:title={'center':'Concrete compressive strength(MPa, megapascals) '}>]],
#       dtype=object)

# %%
plt.figure(figsize=(10,7))
df.corr()['Concrete compressive strength(MPa, megapascals) '].sort_values(ascending=False).drop(["Concrete compressive strength(MPa, megapascals) "])
plt.xlabel("Features",fontsize=14)
plt.ylabel("Correlation with the target columns ",fontsize=14)
plt.title("Corelation of Features with the target column",fontsize=18)
plt.show()

# %%
df.isnull().sum()
# Out:
# Cement (component 1)(kg in a m^3 mixture)                0
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    0
# Fly Ash (component 3)(kg in a m^3 mixture)               0
# Water  (component 4)(kg in a m^3 mixture)                0
# Superplasticizer (component 5)(kg in a m^3 mixture)      0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     0
# Fine Aggregate (component 7)(kg in a m^3 mixture)        0
# Age (day)                                                0
# Concrete compressive strength(MPa, megapascals)          0
# dtype: int64

# %% [markdown]
# none of the columns have NaN or Nat value

# %%
df.skew()
# Out:
# Cement (component 1)(kg in a m^3 mixture)                0.509517
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    0.800737
# Fly Ash (component 3)(kg in a m^3 mixture)               0.537445
# Water  (component 4)(kg in a m^3 mixture)                0.074324
# Superplasticizer (component 5)(kg in a m^3 mixture)      0.908113
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)    -0.040206
# Fine Aggregate (component 7)(kg in a m^3 mixture)       -0.252979
# Age (day)                                                3.269177
# Concrete compressive strength(MPa, megapascals)          0.416922
# dtype: float64

# %% [markdown]
# # Skewness

# %% [markdown]
# From the above observation the Columns falls under high skewness :
#
#   1. Age (day)Skewness=3.26,
#   2. Superplasticizer (component 5)(kg in a m^3 mixture)skewness=0.908,
#   3. Blast Furnace Slag (component 2)(kg in a m^3 mixture) skewness=0.800
#
#
#   But the column have good correlation with the target columns .Dropping of such columns may not be a good approach.

# %% [markdown]
# # Data Transformation

# %% [markdown]
# we need to transform those colmumns which have skewness

# %% [markdown]
# # Checking Outliers

# %%
df['Cement (component 1)(kg in a m^3 mixture)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Blast Furnace Slag (component 2)(kg in a m^3 mixture)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Fly Ash (component 3)(kg in a m^3 mixture)"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Water  (component 4)(kg in a m^3 mixture)"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Superplasticizer (component 5)(kg in a m^3 mixture)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Coarse Aggregate  (component 6)(kg in a m^3 mixture)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Fine Aggregate (component 7)(kg in a m^3 mixture)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Age (day)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
#outliers are present in Age(day)

# %%
df['Concrete compressive strength(MPa, megapascals) '].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking the percentage of Data Falls under outliers

# %%
import numpy as np
import scipy
from scipy import stats
from scipy.stats import zscore
threshold=3
z=np.abs(zscore(df))
np.where(z>3)
# Out:
# (array([  2,   3,   4,   6,  12,  17,  24,  25,  26,  30,  31,  33,  34,
#          35,  41,  42,  56,  60,  61,  63,  65,  66,  76,  79,  99, 102,
#         122, 125, 145, 148, 168, 171, 553, 559, 571, 584, 604, 610, 616,
#         620, 622, 756, 769, 792, 798, 814, 820, 873, 936], dtype=int64),
#  array([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#         4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 1, 1, 1, 7, 7, 7, 7, 7, 7, 7, 7,
#         7, 7, 7, 3, 3], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 5                                         266.0
# 7                                         380.0
# 8                                         266.0
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 5                                                 114.0
# 7                                                  95.0
# 8                                                 114.0
# ...

# %%
df.shape
# Out:
# (1030, 9)

# %% [markdown]
# # Percentage loss of Data while removing Outliers

# %%
percentage_loss=((49)/1030)*100
print(percentage_loss)
# Out:
# 4.757281553398058

# %% [markdown]
# Since the percentage of outliers are less than 5 percent . we can proceed with the outliers removal
#
#
#
# sometimes z-score is unable to remove outlies so we prefer IQR here over z-score

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Cement (component 1)(kg in a m^3 mixture)                157.625000
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    142.950000
# Fly Ash (component 3)(kg in a m^3 mixture)               118.270000
# Water  (component 4)(kg in a m^3 mixture)                 27.100000
# Superplasticizer (component 5)(kg in a m^3 mixture)       10.160000
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)      97.400000
# Fine Aggregate (component 7)(kg in a m^3 mixture)         93.050000
# Age (day)                                                 49.000000
# Concrete compressive strength(MPa, megapascals)           22.429171
# dtype: float64

# %%
df_new1=df[~((df < (Q1 - 1.5 * IQR))| (df > (Q3 + 1.5 * IQR))).any(axis=1)]
print(df_new1.shape)
# Out:
# (941, 9)

# %%
percentage_loss=((1030-941)/1030)*100
print(percentage_loss)
# Out:
# 8.640776699029127

# %% [markdown]
# The Percentage loss in the z-score is less so we prefer z-score over IQR

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %% [markdown]
# # Removing skewness by transforming Data

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method="yeo-johnson")

# %% [markdown]
# # Regressor Model Building

# %% [markdown]
# # Linear Regression:

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_t=sc.fit_transform(x)
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
max_scr=0
for i in range(0,1000):
    train_x,test_x,train_y,test_y=train_test_split(x_t,y,random_state=i,test_size=0.20)
    lr.fit(train_x,train_y)
    pred_train=lr.predict(train_x)
    pred_test=lr.predict(test_x)
    if round(r2_score(train_y,pred_train)*100,2)==round(r2_score(test_y,pred_test)*100,2):
        print("At Random State",i,"The model performs very well")
        print("At Random State i:-",i)
        print("Training r2_score is ",r2_score(train_y,pred_train)*100)
        print("Testing r2_score is  ",r2_score(test_y,pred_test)*100)
# Out:
# At Random State 96 The model performs very well
# At Random State i:- 96
# Training r2_score is  81.21020279049739
# Testing r2_score is   81.20783512781513
# At Random State 375 The model performs very well
# At Random State i:- 375
# Training r2_score is  81.24043703742225
# Testing r2_score is   81.23619020940399

# %%
x_train_b,x_test_b,y_train_b,y_test_b=train_test_split(x_t,y,random_state=96,test_size=0.20)

# %% [markdown]
# We will use Random State 96

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Regularization

# %% [markdown]
# # 1. Lasso:

# %%
from sklearn.linear_model import Lasso
parameters={"alpha":[0.0001,0.001,0.01,0.1,1,10,100],"random_state":list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(train_x,train_y)
print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %%
ls=Lasso(alpha=0.1,random_state=0)
ls.fit(x_train_b,y_train_b)
ls.score(x_train_b,y_train_b)
pred_ls=ls.predict(x_test_b)

lss=r2_score(y_test_b,pred_ls)
for j in range(2,10):
    lsscore=cross_val_score(ls,x_t,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("cross_validation_score is:-",lsc*100)
    print("r2_score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# cross_validation_score is:- 63.71537739864041
# r2_score is:- 81.18536851747797
#
#
# At cv:- 3
# cross_validation_score is:- 72.36499434036675
# r2_score is:- 81.18536851747797
#
#
# At cv:- 4
# cross_validation_score is:- 66.94815570976857
# r2_score is:- 81.18536851747797
#
#
# At cv:- 5
# cross_validation_score is:- 70.39175656583909
# r2_score is:- 81.18536851747797
#
#
# At cv:- 6
# cross_validation_score is:- 69.90189349675174
# r2_score is:- 81.18536851747797
#
#
# At cv:- 7
# cross_validation_score is:- 71.34684956393352
# r2_score is:- 81.18536851747797
#
#
# At cv:- 8
# cross_validation_score is:- 71.41406397796803
# r2_score is:- 81.18536851747797
#
#
# At cv:- 9
# cross_validation_score is:- 71.39788152724485
# r2_score is:- 81.18536851747797

# %%
print("At cv:-",3)
print("Cross Validation Score is ",72.366)
print("r2_score is",81)
# Out:
# At cv:- 3
# Cross Validation Score is  72.366
# r2_score is 81

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
print("Error: ")


print("mean_squared_error",mean_squared_error(y_test_b,pred_ls))
print("mean_absolute_error",mean_absolute_error(y_test_b,pred_ls))
print("root mean squared error",np.sqrt(mean_squared_error(y_test_b,pred_ls)))
# Out:
# Error:
# mean_squared_error 52.43387591162592
# mean_absolute_error 5.625180838557991
# root mean squared error 7.24112393980561

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_ls,color='r')
plt.plot(y_test_b,y_test_b,color='b')
plt.xlabel("Actual Compressive Strength",fontsize=20)
plt.ylabel("Predicted Compressive Strength",fontsize=20)
plt.title("Lasso Regression",fontsize=30)
plt.show()

# %% [markdown]
# The above result shows the data points near the best fit line .Trying model testing with different Algorithm

# %% [markdown]
# # 2. Ridge Regression

# %%
from sklearn.linear_model import Ridge
parameters={"alpha":[.0001,.001,.01,.1,1],"fit_intercept":[True,False],"normalize":[True,False],"copy_X":[True,False],"tol":[.0001,.001,.01,.1,1],"random_state":list(range(0,10))}
rd=Ridge()
clf=GridSearchCV(rd,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'alpha': 0.01, 'copy_X': True, 'fit_intercept': True, 'normalize': True, 'random_state': 0, 'tol': 0.0001}

# %%
rd=Ridge(alpha=0.01,copy_X=True,fit_intercept=True,normalize=True,random_state=0,tol=0.0001)
rd.fit(x_train_b,y_train_b)
rd.score(x_train_b,y_train_b)
pred_rd=rd.predict(x_test_b)

rds=r2_score(y_test_b,pred_rd)
print("R2 Score:",rds*100)

rdscore=cross_val_score(rd,x_t,y,cv=3)
rdc=rdscore.mean()
print("Cross val score",rdc*100)
# Out:
# R2 Score: 81.27068146401652
# Cross val score 71.67672087737029

# %%
print("Error:")


print("mean_squared_error",mean_squared_error(y_test_b,pred_rd))
print("mean_aboslute_error",mean_absolute_error(y_test_b,pred_rd))
print("root mean squared error",np.sqrt(mean_squared_error(y_test_b,pred_rd)))
# Out:
# Error:
# mean_squared_error 52.196120074812804
# mean_aboslute_error 5.609832730337009
# root mean squared error 7.224688233744955

# %%
plt.figure(figsize=(10,7))
plt.scatter(x=y_test_b,y=pred_rd,color='r')
plt.plot(y_test_b,y_test_b,color='lime')
plt.xlabel("Actual Compressive Strength",fontsize=20)
plt.ylabel("Predictive Compressive Strength",fontsize=20)
plt.title("Ridge Regression",fontsize=34)
plt.show()

# %% [markdown]
# # Ensemble Techniques

# %%
from sklearn.tree import DecisionTreeRegressor

parameters={"criterion":["mse","friedman_mse","mae"],"splitter":["best","random"]}
dt=DecisionTreeRegressor()
dt.fit(x_train_b,y_train_b)
clf=GridSearchCV(dt,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'splitter': 'random'}

# %%
dt=DecisionTreeRegressor(criterion="mae",splitter="random")
dt.fit(x_train_b,y_train_b)
dt.score(x_train_b,y_train_b)
pred_dt=dt.predict(x_test_b)

dts=r2_score(y_test_b,pred_dt)
print("r2_score",dts*100)

dtscore=cross_val_score(dt,x_t,y,cv=3)
dtc=dtscore.mean()
print("cross_val_score",dtc*100)
# Out:
# r2_score 83.88891949480448
# cross_val_score 40.381826711756226

# %%
print("Error:")



print("mean squared error",mean_squared_error(y_test_b,pred_dt))
print("mean absolute error",mean_absolute_error(y_test_b,pred_dt))
print("root mean sqaured error",np.sqrt(mean_squared_error(y_test_b,pred_dt)))
# Out:
# Error:
# mean squared error 44.89943886471485
# mean absolute error 4.009443935042097
# root mean sqaured error 6.700704355865498

# %%
plt.figure(figsize=(10,7))
plt.scatter(x=y_test_b,y=pred_dt,color='r')
plt.plot(y_test_b,y_test_b,color='b')
plt.xlabel("Actual compressive strength",fontsize=20)
plt.ylabel("predicted compressive strength",fontsize=20)
plt.title("Decision Tree Regressor",fontsize=30)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

parameters={"criterion":["friedman_mse","mae"],"n_estimators":[100,200,300]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'n_estimators': 300}

# %%
rf=RandomForestRegressor(criterion='mae',n_estimators=300)
rf.fit(x_train_b,y_train_b)
rf.score(x_train_b,y_train_b)
pred_rf=rf.predict(x_test_b)

rfs=r2_score(y_test_b,pred_rf)
print("r2_score=",rfs*100)

rfscore=cross_val_score(rf,x_t,y,cv=3)
rfc=rfscore.mean()
print("Cross Validation score",rfc*100)
# Out:
# r2_score= 92.56026393806121
# Cross Validation score 34.30480368580959

# %%
print("Error:")


print("mean squared error",mean_squared_error(y_test_b,pred_rf))
print("mean absolute error",mean_absolute_error(y_test_b,pred_rf))
print("root mean squared error",np.sqrt(mean_squared_error(y_test_b,pred_rf)))
# Out:
# Error:
# mean squared error 20.733555044611254
# mean absolute error 3.073779009689829
# root mean squared error 4.553411363429759

# %%
plt.figure(figsize=(10,7))
plt.scatter(x=y_test_b,y=pred_rf,color='b')
plt.plot(y_test_b,y_test_b,color='g')
plt.xlabel("Actual Compressive Strength",fontsize=20)
plt.ylabel("Predicted Compressive Strength",fontsize=20)
plt.title("Random Forest Regression",fontsize=30)
plt.show()

# %% [markdown]
# # Support Vector Regressor

# %%
from sklearn.svm import SVR
parameters={"kernel":["rbf","poly","linear","sigmoid","percomputed"],"degree":[0,1,2,3,4],"gamma":["scale","auto"]}
svr=SVR()
clf=GridSearchCV(svr,parameters)
clf.fit(x_train_b,y_train_b)


print(clf.best_params_)
# Out:
# {'degree': 0, 'gamma': 'scale', 'kernel': 'linear'}

# %%
svr=SVR(degree=0,gamma='scale',kernel='linear')
svr.fit(x_train_b,y_train_b)
svr.score(x_train_b,y_train_b)
pred_svr=svr.predict(x_test_b)

svrs=r2_score(y_test_b,pred_svr)
print("r2-score:",svrs*100)

svrscore=cross_val_score(svr,x_t,y,cv=3)
svc=svrscore.mean()
print("Cross Validation Score:",svc*100)
# Out:
# r2-score: 80.95101035762275
# Cross Validation Score: 68.95147660711318

# %%
print("ERROR:")

print("mean sqaured error",mean_squared_error(y_test_b,pred_svr))
print("mean absolute error",mean_absolute_error(y_test_b,pred_svr))
print("root mean sqaured error",np.sqrt(mean_squared_error(y_test_b,pred_svr)))
# Out:
# ERROR:
# mean sqaured error 53.087000937441076
# mean absolute error 5.6179705301539204
# root mean sqaured error 7.286082688073274

# %%
plt.figure(figsize=(10,7))
plt.scatter(x=y_test_b,y=pred_svr,color='black')
plt.plot(y_test_b,y_test_b,color='g')
plt.xlabel("Actual Compressive Strength",fontsize=20)
plt.ylabel("Predictive Compressive Strength",fontsize=20)
plt.title("Support Vector Regressor")
plt.show()

# %% [markdown]
# # The Best model is Decision Tree Regressor .Since the Difference between the percentge score of cross_validation and r2_score is optimum.

# %% [markdown]
# .

# %% [markdown]
# # Model Saving

# %%
import pickle
filename="dt_concrete.pkl"
pickle.dump(dt,open(filename,"wb"))

# %% [markdown]
# # Conclusion

# %%
a=np.array(test_y)
a
# Out:
# array([26.22766704, 42.63719584, 43.37700359, 25.2003478 , 25.10382116,
#        39.1622368 , 36.83870268, 43.49904084, 64.30053176, 33.79811352,
#        45.85429086, 13.29378676, 17.83674412, 41.05346947, 69.65776028,
#        27.53077668, 44.13335876, 42.6440906 , 46.6430514 , 38.07424367,
#        13.39553372, 25.48303296, 33.39959639, 67.69964844, 37.9556538 ,
#        28.096147  , 33.4195912 ,  9.13142014, 24.28334472, 66.42411784,
#        71.98818916, 28.46846404, 20.72564856, 17.36790044, 18.74616296,
#        63.3973182 , 38.99676256, 33.75674496, 23.84897484, 33.05347944,
#        37.43165204, 56.69561148, 35.34253976,  6.46728488, 33.08243743,
#        12.47262084, 40.2309246 , 32.922479  , 45.70536404, 56.8472962 ,
#        52.44154456, 35.34253976, 24.0971862 , 27.66177712, 28.02168359,
#        31.02642   , 50.77301264, 48.79421652, 29.72331036, 61.09446836,
#        32.72253096, 43.0577762 , 54.76507868, 17.54026944, 29.87085822,
# ...

# %%
b=np.array(pred_dt)
b
# Out:
# array([42.6440906 , 13.81709904, 31.2677366 , 56.14403068, 30.12320644,
#        60.2946762 , 23.13881456, 35.17017076, 24.00065956, 60.19814956,
#        39.300132  , 33.70158688, 41.68020315, 60.2946762 , 55.89581932,
#        35.76312012, 40.59634688, 76.23536132, 40.0585556 ,  9.99050724,
#        13.19657064, 37.91428524, 14.69962832, 35.07640202, 77.29715436,
#        31.35047372, 15.08573488, 19.35014394, 67.568648  , 33.70158688,
#        41.09966436,  3.31982694, 44.6118551 , 68.75060685, 41.36856   ,
#        41.36856   , 45.93978588, 31.41942132, 61.88736576, 52.42637609,
#        33.39821744,  9.4458212 , 31.0236621 , 65.19685056, 35.31427124,
#        61.92183956, 12.47262084, 32.9569528 , 15.52631004, 40.8686899 ,
#         8.53640236, 47.73931824, 33.7153764 , 23.8358748 , 10.53588276,
#        24.44881896, 40.2309246 , 17.27551066, 72.09850532, 44.86834018,
#        26.8550902 , 39.48629052,  4.78220554, 17.57612219, 17.24379476,
# ...

# %%
df_c=pd.DataFrame({"actual_value":a,"predcited_value":b},index=range(len(a)))

# %%
df_c
# Out:
#      actual_value  predcited_value
# 0       26.227667        42.644091
# 1       42.637196        13.817099
# 2       43.377004        31.267737
# 3       25.200348        56.144031
# 4       25.103821        30.123206
# ..            ...              ...
# 192     13.713678        49.201007
# 193     33.003837        71.298713
# 194     49.897378        17.576122
# 195     61.232364        57.915984
# 196     59.590426        11.957582
#
# [197 rows x 2 columns]

# %% [markdown]
# # From the above table model is predicted the vlaues with 70-80 percent accuracy.
